# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('http://bit.ly/chiporders')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
mask = df['quantity'] >= 2

# %%
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: quantity, Length: 4622, dtype: bool

# %%
df.loc[mask, :].shape
# Out:
# (267, 5)

# %%
df.loc[mask, :]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 18           9         2         Canned Soda
# 51          23         2         Canned Soda
# 135         60         2  Chicken Salad Bowl
# 148         67         2       Steak Burrito
# ...        ...       ...                 ...
# 4491      1786         4   Canned Soft Drink
# 4499      1789         2   Canned Soft Drink
# 4560      1812         2   Canned Soft Drink
# 4561      1813         2  Chicken Salad Bowl
# 4582      1822         2       Bottled Water
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 18                                             [Sprite]     $2.18
# 51                                       [Mountain Dew]     $2.18
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...    $22.50
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $17.98
# ...

# %%
np.count_nonzero(mask)
# Out:
# 267

# %%
(np.count_nonzero(mask) / df.shape[0]) * 100
# Out:
# 5.776720034617049

# %%
df1 = df.head(4)
df2 = df.loc[3:6]

# %%
df1
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                NaN     $2.39

# %%
cols1 = 'A B C D E'.split(' ')
cols2 = 'F G H I J'.split(' ')
df1.columns = cols1
df2.columns = cols2

# %%
df2
# Out:
#    F  G                                      H  \
# 3  1  1  Chips and Tomatillo-Green Chili Salsa
# 4  2  2                           Chicken Bowl
# 5  3  1                           Chicken Bowl
# 6  3  1                          Side of Chips
#
#                                                    I        J
# 3                                                NaN   $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...  $10.98
# 6                                                NaN   $1.69

# %%
df3 = pd.concat([df1, df2])

# %%
df3
# Out:
#      A    B                                      C             D       E    F  \
# 0  1.0  1.0           Chips and Fresh Tomato Salsa           NaN  $2.39   NaN
# 1  1.0  1.0                                   Izze  [Clementine]  $3.39   NaN
# 2  1.0  1.0                       Nantucket Nectar       [Apple]  $3.39   NaN
# 3  1.0  1.0  Chips and Tomatillo-Green Chili Salsa           NaN  $2.39   NaN
# 3  NaN  NaN                                    NaN           NaN     NaN  1.0
# 4  NaN  NaN                                    NaN           NaN     NaN  2.0
# 5  NaN  NaN                                    NaN           NaN     NaN  3.0
# 6  NaN  NaN                                    NaN           NaN     NaN  3.0
#
#      G                                      H  \
# 0  NaN                                    NaN
# 1  NaN                                    NaN
# 2  NaN                                    NaN
# 3  NaN                                    NaN
# ...

# %%
df4=df3.drop([3])

# %%
df4
# Out:
#      A    B                             C             D       E    F    G  \
# 0  1.0  1.0  Chips and Fresh Tomato Salsa           NaN  $2.39   NaN  NaN
# 1  1.0  1.0                          Izze  [Clementine]  $3.39   NaN  NaN
# 2  1.0  1.0              Nantucket Nectar       [Apple]  $3.39   NaN  NaN
# 4  NaN  NaN                           NaN           NaN     NaN  2.0  2.0
# 5  NaN  NaN                           NaN           NaN     NaN  3.0  1.0
# 6  NaN  NaN                           NaN           NaN     NaN  3.0  1.0
#
#                H                                                  I        J
# 0            NaN                                                NaN      NaN
# 1            NaN                                                NaN      NaN
# 2            NaN                                                NaN      NaN
# 4   Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $16.98
# ...

# %%
df4 = df3.reset_index().drop_duplicates(subset='index', keep='last')          
df4
# Out:
#    index    A    B                             C             D       E    F  \
# 0      0  1.0  1.0  Chips and Fresh Tomato Salsa           NaN  $2.39   NaN
# 1      1  1.0  1.0                          Izze  [Clementine]  $3.39   NaN
# 2      2  1.0  1.0              Nantucket Nectar       [Apple]  $3.39   NaN
# 4      3  NaN  NaN                           NaN           NaN     NaN  1.0
# 5      4  NaN  NaN                           NaN           NaN     NaN  2.0
# 6      5  NaN  NaN                           NaN           NaN     NaN  3.0
# 7      6  NaN  NaN                           NaN           NaN     NaN  3.0
#
#      G                                      H  \
# 0  NaN                                    NaN
# 1  NaN                                    NaN
# 2  NaN                                    NaN
# 4  1.0  Chips and Tomatillo-Green Chili Salsa
# 5  2.0                           Chicken Bowl
# 6  1.0                           Chicken Bowl
# ...

# %%
df3.reset_index()
# Out:
#    index    A    B                                      C             D  \
# 0      0  1.0  1.0           Chips and Fresh Tomato Salsa           NaN
# 1      1  1.0  1.0                                   Izze  [Clementine]
# 2      2  1.0  1.0                       Nantucket Nectar       [Apple]
# 3      3  1.0  1.0  Chips and Tomatillo-Green Chili Salsa           NaN
# 4      3  NaN  NaN                                    NaN           NaN
# 5      4  NaN  NaN                                    NaN           NaN
# 6      5  NaN  NaN                                    NaN           NaN
# 7      6  NaN  NaN                                    NaN           NaN
#
#         E    F    G                                      H  \
# 0  $2.39   NaN  NaN                                    NaN
# 1  $3.39   NaN  NaN                                    NaN
# 2  $3.39   NaN  NaN                                    NaN
# 3  $2.39   NaN  NaN                                    NaN
# ...
